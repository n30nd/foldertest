# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
resnet_avg = [0.5256410256410257, 0.625, 0.625, 0.375, 0.625, 0.6233974358974359, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625]
resnet_prox = [0.6346153846153846, 0.625, 0.625, 0.625, 0.625, 0.375, 0.375, 0.375, 0.625, 0.625, 0.625, 0.6185897435897436, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625]
resnet_nova =  [39.42307692307692, 62.5, 37.5, 39.1025641025641, 62.5, 62.5, 62.33974358974359, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 39.1025641025641, 37.5, 62.5, 37.5, 37.5, 62.5, 37.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 37.5, 62.5, 37.5, 37.5, 62.5, 62.5, 62.5]
resnet_scaffold = [62.33974358974359, 62.5, 37.5, 37.5, 37.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 37.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 37.5, 37.5, 62.5, 62.5, 62.5, 37.5, 37.5, 37.5, 37.5, 62.5, 62.5, 37.5, 62.5, 62.5, 62.5, 62.5, 37.5, 62.5, 62.5, 62.5, 62.5, 37.5, 62.5, 37.5, 37.5, 62.5, 37.5, 37.5, 37.5, 62.5, 37.5, 62.5, 62.5, 37.5, 37.5, 62.5, 37.5, 37.5, 37.5, 62.5, 37.5, 37.5]

resnet_nova = [x/100.0 for x in resnet_nova]
resnet_scaffold = [x/100.0 for x in resnet_scaffold]

# %%
vgg_avg = [0.6217948717948718, 0.625, 0.625, 0.625, 0.625, 0.625, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.6266025641025641, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625]
vgg_prox = [0.625, 0.625, 0.625, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.3766025641025641, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.6266025641025641, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.8012820512820513, 0.375, 0.375, 0.625]
vgg_nova = [0.375, 0.625, 0.375, 0.625, 0.625, 0.625, 0.375, 0.6233974358974359, 0.375, 0.7051282051282052, 0.625, 0.375, 0.375, 0.375, 0.625, 0.625, 0.625, 0.625, 0.7836538461538461, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.47435897435897434, 0.8381410256410257, 0.5016025641025641, 0.625, 0.375, 0.625, 0.47115384615384615, 0.6794871794871795, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.7852564102564102, 0.3974358974358974, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.5721153846153846, 0.375, 0.625, 0.625, 0.625]
vgg_scaffold = [0.5657051282051282, 0.625, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.375, 0.375, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.375, 0.625, 0.625, 0.625, 0.625, 0.625, 0.625, 0.6810897435897436, 0.375, 0.375, 0.375, 0.625, 0.625, 0.375, 0.625]

# %%
# Xác định số vòng (round)
rounds = np.arange(0, len(resnet_avg))

# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))
plt.plot(rounds, resnet_avg, label="ResNet", marker='o')
plt.plot(rounds, vgg_avg, label="VGG", marker='x')

# Thêm nhãn cho trục và tiêu đề
plt.xlabel("Round")
plt.ylabel("Average Accuracy")
plt.title("FedAvg")
plt.legend()

# Đánh dấu các điểm trục hoành chia hết cho 10
xticks = np.arange(10, len(resnet_avg) + 1, 10)
plt.xticks(xticks)  # Đặt các điểm trên trục hoành chia hết cho 10

# Hiển thị biểu đồ
plt.grid(True)
plt.show()

# %%
# Xác định số vòng (round)
rounds = np.arange(0, len(resnet_avg))

# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))
plt.plot(rounds, resnet_prox, label="ResNet", marker='o')
plt.plot(rounds, vgg_prox, label="VGG", marker='x')

# Thêm nhãn cho trục và tiêu đề
plt.xlabel("Round")
plt.ylabel("Average Accuracy")
plt.title("FedProx")
plt.legend()

# Đánh dấu các điểm trục hoành chia hết cho 10
xticks = np.arange(10, len(resnet_avg) + 1, 10)
plt.xticks(xticks)  # Đặt các điểm trên trục hoành chia hết cho 10

# Hiển thị biểu đồ
plt.grid(True)
plt.show()

# %%
# Xác định số vòng (round)
rounds = np.arange(0, len(resnet_avg))

# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))
plt.plot(rounds, resnet_nova, label="ResNet", marker='o')
plt.plot(rounds, vgg_nova, label="VGG", marker='x')

# Thêm nhãn cho trục và tiêu đề
plt.xlabel("Round")
plt.ylabel("Average Accuracy")
plt.title("FedNova")
plt.legend()

# Đánh dấu các điểm trục hoành chia hết cho 10
xticks = np.arange(10, len(resnet_avg) + 1, 10)
plt.xticks(xticks)  # Đặt các điểm trên trục hoành chia hết cho 10

# Hiển thị biểu đồ
plt.grid(True)
plt.show()

# %%
# Xác định số vòng (round)
rounds = np.arange(0, len(resnet_avg))

# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))
plt.plot(rounds, resnet_scaffold, label="ResNet", marker='o')
plt.plot(rounds, vgg_scaffold, label="VGG", marker='x')

# Thêm nhãn cho trục và tiêu đề
plt.xlabel("Round")
plt.ylabel("Average Accuracy")
plt.title("Scaffold")
plt.legend()

# Đánh dấu các điểm trục hoành chia hết cho 10
xticks = np.arange(10, len(resnet_avg) + 1, 10)
plt.xticks(xticks)  # Đặt các điểm trên trục hoành chia hết cho 10

# Hiển thị biểu đồ
plt.grid(True)
plt.show()

# %%
accs = [39.743589743589745, 62.5, 37.5, 62.5, 62.5, 37.5, 37.5, 49.67948717948718, 62.5, 62.5, 58.17307692307692, 62.5, 62.5, 62.5, 62.5, 62.17948717948718, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 52.083333333333336, 62.5, 62.5, 37.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 63.62179487179487, 81.57051282051282, 82.8525641025641, 82.53205128205128, 81.41025641025641, 79.8076923076923, 80.60897435897436, 81.41025641025641, 79.48717948717949, 79.48717948717949, 76.28205128205128, 76.28205128205128, 76.12179487179488, 73.23717948717949, 82.53205128205128, 83.01282051282051, 81.41025641025641, 81.57051282051282, 81.25, 81.57051282051282, 82.05128205128206, 81.73076923076923, 81.73076923076923, 82.05128205128206, 83.01282051282051, 82.8525641025641, 82.05128205128206, 82.8525641025641, 82.21153846153847, 83.01282051282051, 82.8525641025641, 82.05128205128206, 82.21153846153847, 82.8525641025641, 80.92948717948718, 80.92948717948718, 80.92948717948718, 80.76923076923077, 78.52564102564102, 79.00641025641026, 79.96794871794872, 79.8076923076923, 79.8076923076923, 80.92948717948718, 80.76923076923077, 81.57051282051282, 79.96794871794872, 80.76923076923077, 78.52564102564102]
# Xác định số vòng (round)
rounds = np.arange(0, len(accs))

# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))
plt.plot(rounds, accs, label="VGG with FedNova", marker='o')

# Thêm nhãn cho trục và tiêu đề
plt.xlabel("Round")
plt.ylabel("Average Accuracy")
plt.title("VGG with FedNova")
plt.legend()

# Đánh dấu các điểm trục hoành chia hết cho 10
xticks = np.arange(10, len(accs) + 1, 10)
plt.xticks(xticks)  # Đặt các điểm trên trục hoành chia hết cho 10

# Hiển thị biểu đồ
plt.grid(True)
plt.show()
